# %%
import pandas as pd
# Python SQL toolkit and Object Relational Mapper
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine
import pymongo
from pymongo import MongoClient
import os
import json
import datetime

# %%
sentiment = pd.read_csv('AAII-AAII_SENTIMENT.csv')
sentiment
# Out:
#             Date   Bullish   Neutral   Bearish     Total  \
# 0     2018-10-11  0.306061  0.339394  0.354545  1.000000
# 1     2018-10-04  0.456621  0.292237  0.251142  1.000000
# 2     2018-09-27  0.362205  0.326772  0.311024  1.000001
# 3     2018-09-20  0.320423  0.359155  0.320423  1.000001
# 4     2018-09-13  0.320896  0.350746  0.328358  1.000000
# 5     2018-09-06  0.422222  0.314815  0.262963  1.000000
# 6     2018-08-30  0.434959  0.321138  0.243902  0.999999
# 7     2018-08-23  0.384615  0.344729  0.270655  0.999999
# 8     2018-08-16  0.361702  0.347518  0.290780  1.000000
# 9     2018-08-09  0.363636  0.326019  0.310345  1.000000
# 10    2018-08-02  0.291105  0.388140  0.320755  1.000000
# 11    2018-07-26  0.315217  0.415761  0.269022  1.000000
# 12    2018-07-19  0.346633  0.403990  0.249377  1.000000
# 13    2018-07-12  0.430508  0.277966  0.291525  0.999999
# 14    2018-07-05  0.278552  0.328691  0.392758  1.000001
# ...

# %%
energy_df = pd.read_csv('EIA-SEDS_TETCB_US_A.csv')
energy_df.head()
# Out:
#          Date       Value
# 0  2016-12-31  97314710.0
# 1  2015-12-31  97410967.0
# 2  2014-12-31  98391552.0
# 3  2013-12-31  97223138.0
# 4  2012-12-31  94454840.0

# %%
# Create engine using the `demographics.sqlite` database file
engine = create_engine("sqlite:///../Resources/demographics.sqlite")

# %%
# Import SQL Alchemy
from sqlalchemy import create_engine

# Import and establish Base for which classes will be constructed 
from sqlalchemy.ext.declarative import declarative_base
Base = declarative_base()

# Import modules to declare columns and column data types
from sqlalchemy import Column, Integer, String, Float

# %%
from odo import odo
#>>> odo(source, target)  # load source into target
# Out:
# C:\Users\Shail\Anaconda3\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# C:\Users\Shail\Anaconda3\lib\site-packages\odo\backends\pandas.py:102: FutureWarning: pandas.tslib is deprecated and will be removed in a future version.
# You can access NaTType as type(pandas.NaT)
#   @convert.register((pd.Timestamp, pd.Timedelta), (pd.tslib.NaTType, type(None)))

# %%
#odo(energy_df, 'mongodb://hostname/db::collection') # Dump Mongo to DataFrame
odo(energy_df,'mongodb://localhost:27017/test_db::test_collection')
# Out:
# -------------------------------------------------------------------------
# AttributeError                          Traceback (most recent call last)
# <ipython-input-7-c320319ee3ff> in <module>()
#       1 #odo(energy_df, 'mongodb://hostname/db::collection') # Dump Mongo to DataFrame
# ----> 2 odo(energy_df,'mongodb://localhost:27017/test_db::test_collection')
#
# ~\Anaconda3\lib\site-packages\odo\odo.py in odo(source, target, **kwargs)
#      89     odo.append.append      - Add things onto existing things
#      90     """
# ---> 91     return into(target, source, **kwargs)
#
# ~\Anaconda3\lib\site-packages\multipledispatch\dispatcher.py in __call__(self, *args, **kwargs)
#     162             self._cache[types] = func
#     163         try:
# --> 164             return func(*args, **kwargs)
#     165
#     166         except MDNotImplementedError:
#
# ~\Anaconda3\lib\site-packages\odo\into.py in wrapped(*args, **kwargs)
# ...

# %%
from pymongo import MongoClient
client = MongoClient()

# %%
client = MongoClient('localhost', 27017)

# %%
client = MongoClient('mongodb://localhost:27017/')

# %%
odo(energy_df, 'test.csv')

# %%
# Setup connection to mongodb
conn = "mongodb://localhost:27017"
client = pymongo.MongoClient(conn)

# %%
# Select database and collection to use
db = client.test
collection = db.test_stuff

# %%
# ====== Inserting Documents ====== #


# Creating a simple Pandas DataFrame
# liste_hello = ['hello1','hello2']
# liste_world = ['world1','world2']

# df = pd.DataFrame(data = {'hello' : liste_hello, 'world': liste_world})


#df = pd.DataFrame.from_dict({'A': {1: datetime.datetime.now()}})
df = pd.DataFrame.from_dict(energy_df)
df
# Out:
#           Date        Value
# 0   2016-12-31   97314710.0
# 1   2015-12-31   97410967.0
# 2   2014-12-31   98391552.0
# 3   2013-12-31   97223138.0
# 4   2012-12-31   94454840.0
# 5   2011-12-31   96897848.0
# 6   2010-12-31   97543976.0
# 7   2009-12-31   94093700.0
# 8   2008-12-31   98861525.0
# 9   2007-12-31  100991264.0
# 10  2006-12-31   99447077.0
# 11  2005-12-31  100183716.0
# 12  2004-12-31  100097583.0
# 13  2003-12-31   97915776.0
# 14  2002-12-31   97648367.0
# 15  2001-12-31   96143798.0
# 16  2000-12-31   98807639.0
# 17  1999-12-31   96628206.0
# 18  1998-12-31   95029805.0
# 19  1997-12-31   94748492.0
# 20  1996-12-31   94089700.0
# 21  1995-12-31   91093327.0
# 22  1994-12-31   89113599.0
# 23  1993-12-31   87393191.0
# 24  1992-12-31   85787680.0
# 25  1991-12-31   84434783.0
# 26  1990-12-31   84506007.0
# 27  1989-12-31   84776434.0
# 28  1988-12-31   82760410.0
# 29  1987-12-31   79005567.0
# 30  1986-12-31   76639363.0
# 31  1985-12-31   76464077.0
# ...

# %%
records = json.loads(df.T.to_json()).values()
records
# Out:
# dict_values([{'Date': '2016-12-31', 'Value': 97314710.0}, {'Date': '2015-12-31', 'Value': 97410967.0}, {'Date': '2014-12-31', 'Value': 98391552.0}, {'Date': '2013-12-31', 'Value': 97223138.0}, {'Date': '2012-12-31', 'Value': 94454840.0}, {'Date': '2011-12-31', 'Value': 96897848.0}, {'Date': '2010-12-31', 'Value': 97543976.0}, {'Date': '2009-12-31', 'Value': 94093700.0}, {'Date': '2008-12-31', 'Value': 98861525.0}, {'Date': '2007-12-31', 'Value': 100991264.0}, {'Date': '2006-12-31', 'Value': 99447077.0}, {'Date': '2005-12-31', 'Value': 100183716.0}, {'Date': '2004-12-31', 'Value': 100097583.0}, {'Date': '2003-12-31', 'Value': 97915776.0}, {'Date': '2002-12-31', 'Value': 97648367.0}, {'Date': '2001-12-31', 'Value': 96143798.0}, {'Date': '2000-12-31', 'Value': 98807639.0}, {'Date': '1999-12-31', 'Value': 96628206.0}, {'Date': '1998-12-31', 'Value': 95029805.0}, {'Date': '1997-12-31', 'Value': 94748492.0}, {'Date': '1996-12-31', 'Value': 94089700.0}, {'Date': '1995-12-31', 'Value': 91093
# ...

# %%
db.myCollection.insert(records)
# Bulk inserting documents. Each row in the DataFrame will be a document in Mongo
# db.insert_data(df.to_dict('records'))
# db.insert_many(df.to_dict('records'))

print("Data Uploaded!")
# Out:
# Data Uploaded!
# C:\Users\Shail\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: insert is deprecated. Use insert_one or insert_many instead.
#   """Entry point for launching an IPython kernel.
